# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/ibm-nasa-geospatial/Prithvi-EO-2.0-600M
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/ibm-nasa-geospatial/Prithvi-EO-2.0-600M)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
from terratorch.registry import BACKBONE_REGISTRY

model = BACKBONE_REGISTRY.build("ibm-nasa-geospatial/Prithvi-EO-2.0-600M")
